# %%
Airtel_storage = {}

def Airtel_money():
    while True:
        user = input("Enter Airtel money code: ")
        Airtel_code = "*211#"
    
        if user == Airtel_code:
            print("-- WELCOME INTO AIRTEL MONEY ------")
            print("1. Register account\n2. Exit program")
            user_choice = input("Enter the option number: ")
            
            if user_choice == "1":
                Register()
            elif user_choice == "2":
                print("Goodbye")
                break
        else:
            print("Invalid Airtel code")

def Register():
    name = input("Enter your name: ")
    date_birthday = input("Enter your date of birth: ")
    passw = input("Enter your 4-digit password: ")
    if len(passw) != 4 or not passw.isdigit():
        print("Password must be a 4-digit number")
        return
    depot = float(input("Enter amount to deposit into your account: "))
    Airtel_storage[name] = {"date_birthday": date_birthday, "passw": passw, "depot": depot}
    
    print("Your account is now registered")
    print("-------------------------------------------")
    
    while True:
        print("Option List")
        print("1. Buy Airtime/bundle\n2. Send money\n3. Make payment\n4. Withdraw money")
        print("5. Account/pin\n 6. Check Balance\n 7. Depot Airtel Money \n8. Exit")
        choice = input("Enter the option number: ")
        print("-------------------------------------------")

        if choice == "1":
            BuyAirtime(name)
        elif choice == "2":
            SendMoney(name)
        elif choice == "3":
            MakePayment(name)
        elif choice == "4":
            WithdrawMoney(name)
        elif choice == "5":
            AccountPin(name)
        
        elif choice == "6":
            CheckBalance(name)
        elif choice == "7":
            depot_money(name)
        elif choice == "8":
            print("Goodbye")
            break

def BuyAirtime(name):
    depot = Airtel_storage[name]["depot"]
    passw = Airtel_storage[name]["passw"]
    print("Please Select:")
    print("1. Buy Airtime\n2. Buy bundle\n3. Go back\n 00. Go to the Menu")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the option number: ")
    
    if choice1 == "1":
        print("Please Select:")
        print("1. For my number\n2. For another\n3. Go back")
        print("-----------------------------------------------------------")
        choice2 = input("Enter the option number: ")
        
        if choice2 == "1":
            Airtime_amount = float(input("Enter Airtime amount: "))
            Airpass = input("Enter your account pin: ")
            
            if Airtime_amount <= depot and Airpass == passw:
                balance = depot - Airtime_amount
                Airtel_storage[name]["depot"] = balance
                print(f"You have bought Airtime for {Airtime_amount}")
                print(f"Your balance is now: {balance} MWK.")
            elif Airtime_amount > depot and Airpass == passw:
                print("Insufficient balance")
                print("-----------------------------------------------------------")
            else:
                print("Invalid pin")
                print("-----------------------------------------------------------")
        elif choice2 == "2":
            print("Please Enter the phone number of User")
            phone = input("Enter the Phone Number: ")
            Airtime_amount = float(input("Enter Airtime amount: "))
            if len(phone) != 10 or Airtime_amount > depot:
                print("Invalid phone number or insufficient balance")
                print("-----------------------------------------------------------")
            else:
                confirm = input("Enter your account pin: ")
                if confirm == passw:
                    balance = depot - Airtime_amount
                    Airtel_storage[name]["depot"] = balance
                    print(f"You have bought Airtime to : {phone} for {Airtime_amount}")
                    print(f"Your balance is now: {balance} MWK.")
                    print("-----------------------------------------------------------")

    elif choice1 == "2":
        print("Please Select:")
        print("1. Internet bundle\n2. SMS\n3. Go back")
        print("-----------------------------------------------------------")
        choice2 = input("Enter the option number: ")

        if choice2 == "1":
            print("PaNet Mofaya bundle:")
            print("1. Mofaya bundle\n2. Go back")
            print("-----------------------------------------------------------")
            choice3 = input("Enter the option number: ")

            if choice3 == "1":
                print("PaNet Mofaya bundle Daily")
                print("1. 1.7GB, 24hrs K1,000")
                print("2. 800MB, 24hrs K750")
                print("3. 90MB, 24hrs K250")
                print("-----------------------------------------------------------")
                choice4 = input("Enter the option number: ")

                if choice4 == "1":
                    bundle_cost = 1000
                    cout ="1.7GB, 24hrs"
                elif choice4 == "2":
                    bundle_cost = 750
                    cout ="800MB, 24hrs"
                elif choice4 == "3":
                    bundle_cost = 250
                    cout ="90MB, 24hrs"

                choice5 = input("1. Airtime\n2. Airtel Money\nEnter the option number: ")
                print("-----------------------------------------------------------")
                
                if choice5 == "1":
                    print(f"You have received: {cout}")
                    print("-----------------------------------------------------------")
                elif choice5 == "2":
                    Airbuypass = input("Enter your account pin: ")
                    if Airbuypass == passw and depot >= bundle_cost:
                        balance = depot - bundle_cost
                        Airtel_storage[name]["depot"] = balance
                        print(f"You have received: {cout}")
                        print(f"Your balance is now: {balance} MWK.")
                        print("-----------------------------------------------------------")
                    else:
                        print("Invalid pin or insufficient balance")
                        print("-----------------------------------------------------------")
        elif choice2 == "2":
            print("Sms:")
            print("1. sms\n2. Go back")
            print("-----------------------------------------------------------")
            choice3 = input("Enter the option number: ")
            if choice3 == "1":
                print(" Sms")
                print("1. 3000sms, 7days K1,000")
                print("2. 800sms, 3 days K750")
                print("3. 120sms, 24hrs K250")
                print("-----------------------------------------------------------")
                choice4 = input("Enter the option number: ")
                if choice4 == "1":
                    bundle_cost = 1000
                    cout ="3000sms, 7days"
                elif choice4 == "2":
                    bundle_cost = 750
                    cout ="800sms, 3days"
                elif choice4 == "3":
                    bundle_cost = 250
                    cout ="190sms, 24hrs"

                choice5 = input("1. Airtime\n2. Airtel Money\nEnter the option number: ")
                print("-----------------------------------------------------------")
                
                if choice5 == "1":
                    print(f"You have received: {cout}")
                    print("-----------------------------------------------------------")
                elif choice5 == "2":
                    Airbuypass = input("Enter your account pin: ")
                    if Airbuypass == passw and depot >= bundle_cost:
                        balance = depot - bundle_cost
                        Airtel_storage[name]["depot"] = balance
                        print(f"You have received: {cout}")
                        print(f"Your balance is now: {balance} MWK.")
                        print("-----------------------------------------------------------")
                    else:
                        print("Invalid pin or insufficient balance")
                        print("-----------------------------------------------------------")
    
    elif choice1 == "3":
        BuyAirtime(name)
        print("-----------------------------------------------------------")
    
   #


    else:
        print("Error : Invalid Option")
        print("-----------------------------------------------------------")



def SendMoney(name):
    depot = Airtel_storage[name]["depot"]
    passw = Airtel_storage[name]["passw"]
    print("Please Select:")
    print("1. Airtel number\n2. For My Favorite number\n3. Go back")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the option number: ")
    if choice1 == "1":
        print("Please Enter the phone number of User")
        phone = input("Enter the Phone Number: ")
        Airtime_amount = float(input("Enter Airtime amount: "))
        if len(phone) != 10 or Airtime_amount > depot:
            print("Invalid phone number or insufficient balance")
            print("-----------------------------------------------------------")
        else:
            confirm = input("Enter your account pin: ")
            if confirm == passw:
                balance = depot - Airtime_amount
                Airtel_storage[name]["depot"] = balance
                print(f"You have sent Airtime to : {phone} for {Airtime_amount} MWK.")
                print(f"Your balance is now: {balance} MWK.")
                print("-----------------------------------------------------------")

    elif choice1 == "2":
        print("List of favorite Numbers:")
        print("1.0990103315 (kazadi) \n2.0983454356 (marco) \n3.0983426425 (roger)")
        print("-----------------------------------------------------------")
        choice2 = input("Enter the option number: ")

        favory_numbers = {"1": "0990103315 (kazadi)", "2": "0983454356 (marco)", "3": "0983426425 (roger)"}
        favory = favory_numbers.get(choice2, None)

        if favory:
            Airtime_amount = float(input("Enter Airtime amount: "))
            confirm = input("Enter your account pin: ")
            if Airtime_amount > depot:
                print("Insufficient balance")
                print("-----------------------------------------------------------")
            elif confirm != passw:
                print("Invalid pin")
                print("-----------------------------------------------------------")
            else:
                balance = depot - Airtime_amount
                Airtel_storage[name]["depot"] = balance
                print(f"You have sent to : {favory} for {Airtime_amount} MWK.")
                print(f"Your balance is now: {balance} MWK.")
                print("-----------------------------------------------------------")
        else:
            print("Error: Invalid Option")
            print("-----------------------------------------------------------")
            
    elif choice1 == "3":
        print("Going back...")
        
        print("-----------------------------------------------------------")
    
    else:
        print("Error: Invalid Option")
        print("-----------------------------------------------------------")


def MakePayment(name):
    depot = Airtel_storage[name]["depot"]
    passw = Airtel_storage[name]["passw"]
    print("Please Select:")
    print("1. ESCOM\n2. Employer")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the option number: ")
    if choice1 == "1":
        print("Enter the ESCOM Number")
        escom = input("Enter Meter Number: ")
        if len(escom) != 13:
            print("Error: Invalid ESCOM Meter Number! Please ensure the meter number is 13 digits.")
            print("-----------------------------------------------------------")
        else:
            Airtime_amount = float(input("Enter Airtime amount: "))
            confirm = input("Enter your account pin: ")
            if confirm != passw:
                print("Error: Invalid pin!")
                print("-----------------------------------------------------------")
            elif Airtime_amount > depot:
                print("Error: Insufficient balance!")
                print("-----------------------------------------------------------")
            else:
                balance = depot - Airtime_amount
                Airtel_storage[name]["depot"] = balance
                print(f"You have bought ESCOM to: {escom} for {Airtime_amount} MWK.")
                print(f"Your balance is now: {balance} MWK.")
                print("-----------------------------------------------------------")

    
    elif choice1 == "2":
        print("MakePayment for Your Entreprise")
        print("-----------------------------------------------------------")
        entrep = input("Enter Entreprise's name : ")
        Empl_number = int(input("Enter The  Number of Employer: "))
        Ent_id = input("Enter The Entreprise (ID) : ")
        Airtime_amount = float(input("Enter Airtime amount: "))
        confirm = int(input("Enter your pin: "))
        payment = Airtime_amount // Empl_number
        if Airtime_amount > depot and confirm == passw:
            print("Error :  insufficient balance !! ")
            print("-----------------------------------------------------------")
        elif Airtime_amount <= depot and confirm != passw:
            print("Error :  Invalid Pin !! ")
            print("-----------------------------------------------------------")

        elif Airtime_amount != depot and confirm != passw:
             print("Error :  Invalid Pin !!")
             print("Error :  insufficient balance !!")
             print("-----------------------------------------------------------")
        elif confirm == passw and Airtime_amount <= depot:
             balance = depot - Airtime_amount
             Airtel_storage[name]["depot"] = balance
             print(f"You MakePayment to : {entrep} With This Id : {Ent_id} for {Airtime_amount} MWK.")
             print(f"Number of Employer is : {Empl_number}")
             print(f"Each Employer Receive the Amount of : {payment}")
             print(f"Your balance is now: {balance} MWK.")
             print("-----------------------------------------------------------")

    
    else:
        print("Error : Invalid Option")
        print("-----------------------------------------------------------")



        


def WithdrawMoney(name):
    if name not in Airtel_storage:
        print("Error: User not found.")
        return

    depot = Airtel_storage[name]["depot"]
    passw = Airtel_storage[name]["passw"]

    print("Please Select:")
    print("1. US\n2. MWK")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the option number: ").strip()

    if choice1 == "1":
        currency = "US"
    elif choice1 == "2":
        currency = "MWK"
    else:
        print("Error: Invalid Option")
        return

    print("-----------------------------------------------------------")
    print("1. For Agent\n2. For Customer User")
    print("-----------------------------------------------------------")
    choice2 = input("Enter the option number: ").strip()

    if choice2 == "1":
        user_type = "Agent"
        num_len = 8
    elif choice2 == "2":
        user_type = "Customer User"
        num_len = 10
    else:
        print("Error: Invalid Option")
        return

    print(f"Withdraw Money in {currency} With {user_type} Numbers")
    print("-----------------------------------------------------------")

    Agent = input(f"Please Enter the {user_type} Number: ").strip()
    
    if len(Agent) != num_len or not Agent.isdigit():
        print(f"Error: Invalid {user_type} Number. {user_type} Numbers Must Be {num_len} digits.")
        return

    
    try:
        Airtime_amount = float(input("Enter Airtime amount: ").strip())
    except ValueError:
        print("Error: Invalid amount. Please enter a valid number.")
        return

    if Airtime_amount <= 0:
        print("Error: Amount must be greater than zero.")
        return

    if Airtime_amount > depot:
        print("Error: Insufficient balance!")
        return

    
    try:
        confir = input("Enter your pin: ").strip()
    except ValueError:
        print("Error: Invalid pin format. Please enter a numeric pin.")
        return

    if confir != passw:
        print("Error: Invalid Account Pin")
        return
    balance = depot - Airtime_amount
    Airtel_storage[name]["depot"] = balance

    print(f"You have withdrawn money to: {Agent} with this amount: {Airtime_amount} {currency}.")
    print(f"Your balance is now: {balance} {currency}.")
    print("-----------------------------------------------------------")



            

   

def AccountPin(name):
    passw = Airtel_storage[name]["passw"]
    print("Please Select:")
    print("1. Change Account Pin")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the option number: ")
    if choice1 == "1":
        print("Change Account Pin:")
        print("---------------------------")
        Old_Pin = input("Please Enter the Old Pin:")
        New_Pin = input("Please Enter the New Pin (4 digits):")
        
        if Old_Pin != passw:
            print("Error: Invalid Old pin!")
            print("-----------------------------------------------------------")
        elif len(New_Pin) != 4:
            print("Error: New Pin must be 4 digits!")
            print("-----------------------------------------------------------")
        else:
            Airtel_storage[name]["passw"] = New_Pin
            print("Your Pin has been changed successfully. Use your new Account Pin next time.")
            print("-----------------------------------------------------------")
        
    
    else:
        print("Error: Invalid Option")
        print("-----------------------------------------------------------")




def CheckBalance(name):
    if name not in Airtel_storage:
        print("Error: User not found.")
        print("-----------------------------------------------------------")
        return

    depot = Airtel_storage[name]["depot"]
    passw = Airtel_storage[name]["passw"]

    print("Check Your Balance")
    print("1. US\n2. MWK\n3. Go back")
    print("-----------------------------------------------------------")
    choice1 = input("Enter the Option Number: ").strip()

    if choice1 in ["1", "2"]:
        currency = "US" if choice1 == "1" else "MWK"
        print(f"Check Your Balance In {currency}")
        
        check_pin = input("Enter Your Account Pin: ").strip()
        
        if check_pin != passw:
            print("Error: Invalid Account Pin")
        else:
            print(f"Your Balance Is: {depot} {currency}.")
        
        print("-----------------------------------------------------------")

    elif choice1 == "3":
        print("Going back...")

        print("-----------------------------------------------------------")

    else:
        print("Error: Invalid Option")
        print("-----------------------------------------------------------")

    
def depot_money(name):
    if name not in Airtel_storage:
        print("Error: User not found.")
        print("-----------------------------------------------------------")
        return

    print("===== Depot Money =====")
    
    try:
        money = float(input("Enter the amount to deposit into your account: ").strip())
        
        if money <= 0:
            print("Error: Deposit amount must be greater than zero.")
            return
        
        Airtel_storage[name]["depot"] += money

        print(f"Success! {money} has been deposited into your account.")
        print(f"Your new balance is: {Airtel_storage[name]['depot']} MWK")
        print("-----------------------------------------------------------")

    except ValueError:
        print("Error: Invalid amount. Please enter a numeric value.")
        print("-----------------------------------------------------------")


   
Airtel_money()
# Out:
# Enter Airtel money code:  3
# Invalid Airtel code
# Enter Airtel money code:  *211#
# -- WELCOME INTO AIRTEL MONEY ------
# 1. Register account
# 2. Exit program
# Enter the option number:  2
# Goodbye
